# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv(r"C:\Users\User\Documents\2303737710422082\ex2\internet_usage.csv")
data.head()
# Out:
#    Student_ID  Online_Class_Hours  Non_Class_Internet_Hours  \
# 0           1                   1                       3.2
# 1           2                   2                       2.8
# 2           3                   3                       3.5
# 3           4                   4                       2.4
# 4           5                   5                       3.1
#
#    Total_Internet_Usage_Hours Device_Type Network_Type
# 0                         4.5      Mobile         WiFi
# 1                         5.1      Laptop         WiFi
# 2                         6.9      Mobile  Mobile Data
# 3                         6.6      Laptop         WiFi
# 4                         8.4      Mobile         WiFi

# %%
X = data[['Online_Class_Hours']]        # Independent Variable
Y = data['Total_Internet_Usage_Hours'] # Dependent Variable

# %%
model = LinearRegression()

# %%
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
comparison = pd.DataFrame({
    "Online_Class_Hours": X.values.flatten(),
    "Actual_Usage": Y.values,
    "Predicted_Usage": predicted_usage
})

comparison.head()
# Out:
#    Online_Class_Hours  Actual_Usage  Predicted_Usage
# 0                   1           4.5         5.032207
# 1                   2           5.1         5.898916
# 2                   3           6.9         6.765625
# 3                   4           6.6         7.632334
# 4                   5           8.4         8.499042

# %%
plt.scatter(X, Y)
plt.plot(X, predicted_usage)
plt.xlabel("Online Class Hours")
plt.ylabel("Total Internet Usage (Hours)")
plt.title("Linear Regression Analysis")
plt.show()
